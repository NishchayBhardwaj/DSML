# %% [markdown]
# # Importing suitable Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
temp = pd.read_csv('/content/temperatures.csv')

# %%
temp.head()
# Out:
#    YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# 0  1901  22.40  24.14  29.07  31.91  33.41  33.18  31.21  30.39  30.47  29.97
# 1  1902  24.93  26.58  29.77  31.78  33.73  32.91  30.92  30.73  29.80  29.12
# 2  1903  23.44  25.03  27.83  31.39  32.91  33.00  31.34  29.98  29.85  29.04
# 3  1904  22.50  24.73  28.21  32.02  32.64  32.07  30.36  30.09  30.04  29.20
# 4  1905  22.00  22.83  26.68  30.01  33.32  33.25  31.44  30.68  30.12  30.67
#
#      NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 0  27.31  24.49   28.96    23.27    31.46    31.27    27.25
# 1  26.31  24.04   29.22    25.75    31.76    31.09    26.49
# 2  26.08  23.65   28.47    24.24    30.71    30.92    26.26
# 3  26.36  23.63   28.49    23.62    30.95    30.66    26.40
# 4  27.52  23.82   28.30    22.25    30.00    31.33    26.57

# %%
temp.tail()
# Out:
#      YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP  \
# 112  2013  24.56  26.59  30.62  32.66  34.46  32.44  31.07  30.76  31.04
# 113  2014  23.83  25.97  28.95  32.74  33.77  34.15  31.85  31.32  30.68
# 114  2015  24.58  26.89  29.07  31.87  34.09  32.48  31.88  31.52  31.55
# 115  2016  26.94  29.72  32.62  35.38  35.72  34.03  31.64  31.79  31.66
# 116  2017  26.45  29.46  31.60  34.95  35.84  33.82  31.88  31.72  32.22
#
#        OCT    NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 112  30.27  27.83  25.37   29.81    25.58    32.58    31.33    27.83
# 113  30.29  28.05  25.08   29.72    24.90    31.82    32.00    27.81
# 114  31.04  28.10  25.67   29.90    25.74    31.68    31.87    28.27
# 115  31.98  30.11  28.01   31.63    28.33    34.57    32.28    30.03
# 116  32.29  29.60  27.18   31.42    27.95    34.13    32.41    29.69

# %%
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   YEAR     117 non-null    int64
#  1   JAN      117 non-null    float64
#  2   FEB      117 non-null    float64
#  3   MAR      117 non-null    float64
#  4   APR      117 non-null    float64
#  5   MAY      117 non-null    float64
#  6   JUN      117 non-null    float64
#  7   JUL      117 non-null    float64
#  8   AUG      117 non-null    float64
#  9   SEP      117 non-null    float64
#  10  OCT      117 non-null    float64
#  11  NOV      117 non-null    float64
#  12  DEC      117 non-null    float64
#  13  ANNUAL   117 non-null    float64
#  14  JAN-FEB  117 non-null    float64
#  15  MAR-MAY  117 non-null    float64
#  16  JUN-SEP  117 non-null    float64
#  17  OCT-DEC  117 non-null    float64
# dtypes: float64(17), int64(1)
# memory usage: 16.6 KB

# %%
temp.shape
# Out:
# (117, 18)

# %%
temp.describe()
# Out:
#               YEAR         JAN         FEB         MAR         APR  \
# count   117.000000  117.000000  117.000000  117.000000  117.000000
# mean   1959.000000   23.687436   25.597863   29.085983   31.975812
# std      33.919021    0.834588    1.150757    1.068451    0.889478
# min    1901.000000   22.000000   22.830000   26.680000   30.010000
# 25%    1930.000000   23.100000   24.780000   28.370000   31.460000
# 50%    1959.000000   23.680000   25.480000   29.040000   31.950000
# 75%    1988.000000   24.180000   26.310000   29.610000   32.420000
# max    2017.000000   26.940000   29.720000   32.620000   35.380000
#
#               MAY         JUN         JUL         AUG         SEP         OCT  \
# count  117.000000  117.000000  117.000000  117.000000  117.000000  117.000000
# mean    33.565299   32.774274   31.035897   30.507692   30.486752   29.766581
# std      0.724905    0.633132    0.468818    0.476312    0.544295    0.705492
# ...

# %% [markdown]
# # SCATTER PLOT

# %%
arr = np.array(["JAN","FEB","MAR","APR","MAY","JUN","JUL","AUG","SEP","OCT","NOV","DEC"])

isTrue = True
while(isTrue):
  Temp = input("Enter first 3 letters of the Month: ").upper()
  if Temp in arr:
    x = temp["YEAR"].values.reshape(-1, 1)
    y = temp[Temp].values.reshape(-1,1)
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 35)
    model = LinearRegression()
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    print("Intercept:", model.intercept_)
    print("Coefficient", model.coef_)
    plt.scatter(x_test, y_test, color='blue')
    plt.plot(x_test, y_pred, color='yellow')
    plt.xlabel("Year")
    plt.ylabel("Temperature")
    plt.title("Temperature vs Year")
    plt.show()
    print()
    print("Mean Absolute Error: ", metrics.mean_absolute_error(y_test, y_pred))
    print("Mean Squared Error: ", metrics.mean_squared_error(y_test, y_pred))
    print("R2 Score: ", metrics.r2_score(y_test, y_pred))
    isTrue = False
  else:
    print("Invalid month!")
# Out:
# Enter first 3 letters of the Month: may
# Intercept: [17.40716725]
# Coefficient [[0.00821853]]
# Mean Absolute Error:  0.5800448879889322
# Mean Squared Error:  0.48610952085488934
# R2 Score:  0.06301046348869066

# %%
arr = np.array(["JAN","FEB","MAR","APR","MAY","JUN","JUL","AUG","SEP","OCT","NOV","DEC"])

for Temp in arr:
    x = temp["YEAR"].values.reshape(-1, 1)
    y = temp[Temp].values.reshape(-1,1)
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 35)
    model = LinearRegression()
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    year = x_test.flatten()
    plt.scatter(x_test, y_test, color='blue')
    plt.plot(x_test, y_pred, color='yellow')
    plt.xlabel("Year")
    plt.ylabel("Temperature")
    plt.title(f"Temperature vs Year ({Temp})")
    plt.show()
    print()
    print("Mean Absolute Error: ", metrics.mean_absolute_error(y_test, y_pred))
    print("Mean Squared Error: ", metrics.mean_squared_error(y_test, y_pred))
    print("R2 Score: ", metrics.r2_score(y_test, y_pred))
    print()
# Out:
# Intercept: [-2.9439045]
# Coefficient [[0.01359791]]
# Mean Absolute Error:  0.5701146631988522
# Mean Squared Error:  0.5980538968236232
# R2 Score:  0.30890989789419
# Intercept: [-15.75173138]
# Coefficient [[0.02113239]]
# Mean Absolute Error:  0.6820757726818804
# Mean Squared Error:  0.8749185520151301
# R2 Score:  0.3979462968748533
# Intercept: [-1.74334357]
# Coefficient [[0.01574209]]
# Mean Absolute Error:  0.6890229610821671
# Mean Squared Error:  0.8490963401028373
# R2 Score:  0.38973294375021583
# Intercept: [4.53061552]
# Coefficient [[0.01398459]]
# Mean Absolute Error:  0.5364080732864492
# Mean Squared Error:  0.6001257473359007
# R2 Score:  0.21780525289968322
# Intercept: [17.40716725]
# Coefficient [[0.00821853]]
# Mean Absolute Error:  0.5800448879889322
# Mean Squared Error:  0.48610952085488934
# R2 Score:  0.06301046348869066
# Intercept: [20.17134852]
# Coefficient [[0.00640839]]
# Mean Absolute Error:  0.35161210899793965
# ...
